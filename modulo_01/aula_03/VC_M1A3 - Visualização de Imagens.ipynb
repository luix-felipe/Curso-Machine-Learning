# %% [markdown]
# # M1A3 - Visualização de Imagens

# %% [markdown]
# Nessa aula vamos aprender como visualizar imagens utilizando [matplotlib](https://matplotlib.org/)
#
# Esse notebook está estruturado da seguinte forma.
#
# - Instalação
# - Ler imagens do disco
# - Visualizar imagens
# - Próximos passos
# - Atividade Complementares

# %% [markdown]
# ## Instalação e Importação da Biblioteca

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in ./.env-trilha-vc/lib/python3.10/site-packages (3.10.7)
# Requirement already satisfied: cycler>=0.10 in ./.env-trilha-vc/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pyparsing>=3 in ./.env-trilha-vc/lib/python3.10/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.env-trilha-vc/lib/python3.10/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in ./.env-trilha-vc/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.env-trilha-vc/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pillow>=8 in ./.env-trilha-vc/lib/python3.10/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./.env-trilha-vc/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in ./.env-trilha-vc/lib/python3.10/site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: numpy>=1.23 in ./.env-trilha-vc/lib/python3.10/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: six>=1.5 in ./.env-trilha-vc/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Ler Imagens do Disco

# %% [markdown]
# Nossa primeira tarefa é a de ler imagens do disco.
#
# Para isso utilizamos a função `plt.imread`

# %%
# TODO Atualize o path da imagem.
image = plt.imread("praticas/modulo_1/aula_3/bahia.jpeg")

# %% [markdown]
# É possível observar qual o tipo de dados do objeto `image` e visualizar os valores de cada pixel da imagem.

# %%
print(type(image))
# Out:
# <class 'numpy.ndarray'>

# %%
image[0,0]
# Out:
# array([  9, 172, 231], dtype=uint8)

# %% [markdown]
# ## Visualizar Imagens

# %% [markdown]
# Agora que já temos a imagem salva em memória precisamos visualizar ela.
#
# Para isso utilizamos a função `plt.imshow`.

# %%
plt.imshow(image)

# %% [markdown]
# Com isso concluímos a parte prática da aula de hoje.

# %% [markdown]
# ## Próximos Passos e Referências

# %% [markdown]
# Nas próximas aulas iremos aprender a trabalhar com mais bibliotecas utilizadas no dia a dia de profissionais de visão computacional.
#
# Uma lista não exaustiva de referências segue:
#
# - https://matplotlib.org/stable/
# - https://matplotlib.org/stable/tutorials/images.html

# %% [markdown]
# ## Atividades Complementares (Opicional)

# %% [markdown]
# - [ ] Leia a outra imagem do arquivo `rio.jpeg` e rode todos os comandos
# - [ ] Altere o espaço de cores e veja como ficam as imagens.
# - [ ] Podemos visualizar imagens que não foram lidas do disco utilizando `plt.imread`? Talvez criando vetores em `numpy`?
