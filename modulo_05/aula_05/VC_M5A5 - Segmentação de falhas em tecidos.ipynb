# %% [markdown]
# # M5A5 - Segmentação de Falhas em Tecidos

# %% [markdown]
# Na prática de hoje vamos refinar um modelo para a tarefa de segmentação de falhas em tecidos.
#
# Esse notebook está estruturado da seguinte forma.
#
# - Introdução
# - Carregar Base de Dados
# - Refinar Modelo
# - Validar Modelo
# - Próximos passos
# - Atividade Complementares

# %% [markdown]
# ## Introdução

# %% [markdown]
# Instalação para os que ainda não possuem a biblioteca instalada.

# %%
# !pip install torch torchvision tqdm ipywidgets
# Out:
# Requirement already satisfied: torch in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (2.9.1)
# Requirement already satisfied: torchvision in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (0.24.1)
# Requirement already satisfied: tqdm in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (4.67.1)
# Requirement already satisfied: ipywidgets in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (8.1.8)
# Requirement already satisfied: jinja2 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from torch) (11.3.3.83)
# Requirement already satisfied: networkx>=2.5.1 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from torch) (12.8.90)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from torch) (4.15.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from torch) (12.5.8.93)
# Requirement already satisfied: triton==3.5.1 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from torch) (3.5.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from torch) (12.8.93)
# Requirement already satisfied: fsspec>=0.8.5 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from torch) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from torch) (1.13.1.3)
# Requirement already satisfied: filelock in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from torch) (3.20.1)
# Requirement already satisfied: sympy>=1.13.3 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from torch) (1.14.0)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from torch) (12.8.90)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: numpy in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: traitlets>=4.3.1 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: comm>=0.1.3 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: ipython>=6.1.0 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from ipywidgets) (8.37.0)
# Requirement already satisfied: jedi>=0.16 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: exceptiongroup in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.3.1)
# Requirement already satisfied: pygments>=2.4.0 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: matplotlib-inline in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: decorator in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: stack_data in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: executing>=1.2.0 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)

# %% [markdown]
# Importar as bibliotecas

# %%
import torch
import torchvision
from tqdm.notebook import tqdm

# %% [markdown]
# ## Carregar Base de Dados
#
# A primeira tarefa para refinar um modelo é criar a base de dados.
#
# Referência: https://docs.pytorch.org/vision/main/generated/torchvision.datasets.DTD.html

# %%
# Define transforms: Resize and normalize images as expected by most pre-trained models (e.g., ImageNet models use 224x224 input).
# Data augmentation is also crucial for better performance.
image_transforms = torchvision.transforms.Compose([
    torchvision.transforms.Resize(256),
    torchvision.transforms.CenterCrop(224), # Common input size for ImageNet models
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load the dataset
# Set download=True to automatically fetch the dataset if not already present
train_dataset = torchvision.datasets.DTD(root="./data", split="train", download=True, transform=image_transforms)
val_dataset = torchvision.datasets.DTD(root="./data", split="val", download=True, transform=image_transforms)
test_dataset = torchvision.datasets.DTD(root="./data", split="test", download=True, transform=image_transforms)

# Define DataLoaders
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)
_ = torch.utils.data.DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=1, shuffle=False)

# %% [markdown]
# ## Refinar Modelo
#
# Na prática de hoje iremos refinar o modelo **ResNets** disponível no torchvision.

# %%
model = torchvision.models.resnet18(weights=torchvision.models.ResNet18_Weights.DEFAULT)

num_classes = 47

# Get the number of input features for the final layer
in_features = model.fc.in_features

# Replace the existing fully connected layer with a new one
model.fc = torch.nn.Linear(in_features, num_classes)

# Move the model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

criterion = torch.nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Treinamento do modelo
model.train()
epochs = 100 # Alterar para treinar mais epocas.
for epoch in tqdm(range(epochs)):
    iteration = 0
    for images, labels in train_loader:

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if iteration % 100 == 0:
            print(f"Total loss: {loss.item()}")
        iteration += 1
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Total loss: 4.129215240478516
# Total loss: 2.498401641845703
# Total loss: 1.692678451538086
# Total loss: 1.2997723817825317
# Total loss: 1.028595209121704
# Total loss: 1.004145860671997
# Total loss: 0.5832077264785767
# Total loss: 0.5114887356758118
# Total loss: 0.4395548105239868
# Total loss: 0.33516615629196167
# Total loss: 0.2254084050655365
# Total loss: 0.26441746950149536
# Total loss: 0.20267868041992188
# Total loss: 0.09835848212242126
# Total loss: 0.11594346165657043
# Total loss: 0.0841384008526802
# Total loss: 0.08286389708518982
# Total loss: 0.11256883293390274
# Total loss: 0.08622539043426514
# Total loss: 0.08969129621982574
# Total loss: 0.05857635661959648
# Total loss: 0.09913458675146103
# Total loss: 0.0376826673746109
# Total loss: 0.08283917605876923
# Total loss: 0.07110682874917984
# Total loss: 0.01985970139503479
# Total loss: 0.03303223103284836
# Total loss: 0.03441348671913147
# Total loss: 0.02725941501557827
# Total loss: 0.022226814180612564
# Total loss: 0.03698214143514633
# Total loss: 0.03319317847490311
# Total loss: 0.013129005208611488
# Total loss: 0.029555033892393112
# Total loss: 0.02823137678205967
# Total loss: 0.019492410123348236
# Total loss: 0.012854145839810371
# Total loss: 0.02266683056950569
# Total loss: 0.02673981711268425
# Total loss: 0.020641563460230827
# Total loss: 0.019182376563549042
# Total loss: 0.02019665390253067
# Total loss: 0.013525143265724182
# Total loss: 0.026455238461494446
# Total loss: 0.01614430733025074
# Total loss: 0.024745436385273933
# Total loss: 0.01221969909965992
# Total loss: 0.009997544810175896
# Total loss: 0.007608674466609955
# Total loss: 0.014471650123596191
# Total loss: 0.011492094025015831
# Total loss: 0.013305390253663063
# Total loss: 0.031279779970645905
# Total loss: 0.008766481652855873
# Total loss: 0.029317418113350868
# Total loss: 0.016079450026154518
# Total loss: 0.008687086403369904
# Total loss: 0.01313106156885624
# Total loss: 0.008184798993170261
# Total loss: 0.013407031074166298
# Total loss: 0.006439658813178539
# Total loss: 0.006693705916404724
# Total loss: 0.014221291989088058
# Total loss: 0.009539401158690453
# Total loss: 0.013745566830039024
# Total loss: 0.013883886858820915
# Total loss: 0.005740185268223286
# Total loss: 0.019059043377637863
# Total loss: 0.008223148062825203
# Total loss: 0.012789442203938961
# Total loss: 0.007869800552725792
# Total loss: 0.00500662624835968
# Total loss: 0.003624970093369484
# Total loss: 0.010909982956945896
# Total loss: 0.0031431717798113823
# Total loss: 0.0028435401618480682
# Total loss: 0.010872432962059975
# Total loss: 0.005822636652737856
# Total loss: 0.010115130804479122
# Total loss: 0.006961405277252197
# Total loss: 0.010522563010454178
# Total loss: 0.015045716427266598
# Total loss: 0.006877194158732891
# Total loss: 0.00655362056568265
# Total loss: 0.00302098854444921
# Total loss: 0.003013193141669035
# Total loss: 0.003998810425400734
# Total loss: 0.0066775185987353325
# Total loss: 0.006858517415821552
# Total loss: 0.016384020447731018
# Total loss: 0.004216464702039957
# Total loss: 0.006772533059120178
# Total loss: 0.0024721017107367516
# Total loss: 0.009755860082805157
# Total loss: 0.003915106877684593
# Total loss: 0.006152743939310312
# Total loss: 0.007756941020488739
# Total loss: 0.002641153521835804
# Total loss: 0.0074428534135222435
# Total loss: 0.003788500092923641

# %% [markdown]
# ## Validar Modelo
#
# Agora vamos testar o nosso modelo.

# %%
num_correct = 0
num_samples = 0
    
# Set model to evaluation mode
model.eval()

# Disable gradient calculation for inference
with torch.no_grad():
    for images, labels in test_loader:
            x = images.to(device)
            y = labels.to(device)

            scores = model(x)

            # Get the index (class) with the highest score
            _, predictions = scores.max(1)
            
            # Count correct predictions
            num_correct += (predictions == y).sum().item()
            # Count total samples
            num_samples += predictions.size(0)

    # Calculate and print accuracy
    accuracy = float(num_correct) / float(num_samples) * 100
    print(f'Got {num_correct} / {num_samples} with accuracy {accuracy:.2f}%')
# Out:
# Got 1240 / 1880 with accuracy 65.96%

# %% [markdown]
# ## Próximos Passos e Referências

# %% [markdown]
# Nas próximas práticas vamos continuar trabalhando com problemas reais que envolvem Visão Computacional.
#
# Uma lista não exaustiva de referências segue:
#
# - https://docs.pytorch.org/vision/main/generated/torchvision.datasets.DTD.html
# - https://docs.pytorch.org/vision/main/models/generated/torchvision.models.resnet18.html
# - https://huggingface.co/datasets
# - https://pytorch.org/
# - https://docs.pytorch.org/vision/main/models.html
# - https://opencv.org/
# - https://learnopencv.com/blogs/
# - https://pyimagesearch.com/

# %% [markdown]
# ## Atividades Complementares (Opcional)

# %% [markdown]
# - [ ] Tente por menos tempo faz com que a perfomance do modelo matenha-se a mesma?
# - [ ] Tente alterar alguns hiperparâmetros de treinamento, batch e learning rate e veja como isso altera os resultados.
